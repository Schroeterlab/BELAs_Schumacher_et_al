# %% [markdown]
# The Thowfeequ raw data was obtained as two h5ad files. Compression is changed to gzip with anndata in order to open it in R.

# %%
import anndata

# %%
adata = anndata.read("./Data/Thowfeequ_dataset/Thowfeequ_norm_counts/norm_data_55.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 255 × 54737
#     obs: 'Run lane', 'Cell#', 'Stage', 'gene count', 'gene count rpm', 'fraction mapped', 'fraction mito', 'fraction spike-in', 'total reads (log10)'

# %%
adata.obs
# Out:
#                   Run lane  Cell# Stage  gene count  gene count rpm  \
# index
# SS.sc7784898  SS-sc7784898      1  E5.5        8837            7168
# SS.sc7784899  SS-sc7784899      1  E5.5        8611            7134
# SS.sc7784900  SS-sc7784900      1  E5.5        8279            6916
# SS.sc7784902  SS-sc7784902      1  E5.5        8073            6650
# SS.sc7784903  SS-sc7784903      1  E5.5        8719            7030
# ...                    ...    ...   ...         ...             ...
# SS.sc7785265  SS-sc7785265      1  E5.5        8826            7626
# SS.sc7785266  SS-sc7785266      1  E5.5        6392            5015
# SS.sc7785267  SS-sc7785267      1  E5.5        9166            7423
# SS.sc7785268  SS-sc7785268      1  E5.5        8686            7309
# SS.sc7785269  SS-sc7785269      1  E5.5        8588            6919
#
#               fraction mapped  fraction mito  fraction spike-in  \
# index
# SS.sc7784898         0.720346       0.012500           0.007376
# ...

# %%
adata.write("./Data/Thowfeequ_dataset/Thowfeequ_norm_counts/norm_data_55.gzip.h5ad", compression="gzip")

# %%
adata = anndata.read("./Data/Thowfeequ_dataset/Thowfeequ_norm_counts/norm_data_625.h5ad")
adata
adata.write("./Data/Thowfeequ_dataset/Thowfeequ_norm_counts/norm_data_625.gzip.h5ad", compression="gzip")
